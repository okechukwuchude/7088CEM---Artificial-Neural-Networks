# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.layers import SimpleRNN, LSTM, GRU, Dense
from tensorflow.keras.models import Sequential

# %%
data = pd.read_csv(r"C:\Users\okechukwu chude\Documents\Neural Network\7088CEM---Artificial-Neural-Networks\GOOG.csv")
data=data.copy()
data.head()
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %%
print("Total number of days: ",data.shape[0])
# Out:
# Total number of days:  1258

# %% [markdown]
# Checking for Missing Values

# %%
print("Null values:", data.isnull().values.sum())
print("NA values:", data.isna().values.any())
# Out:
# Null values: 0
# NA values: False

# %%
data = data.drop(['symbol'],axis=1)

# %%
#splitting date column to date and time
data['date']= data['date'].str.split(" ", n = 1, expand = True)[0]
data['date']= pd.to_datetime(data['date'])

# %%
# Resample data to hourly basis
df = data.set_index('date').resample('m').first()

# %%
df.head(3)
# Out:
#              close    high       low    open   volume  adjClose  adjHigh  \
# date
# 2016-06-30  718.27  722.47  713.1200  716.48  1306065    718.27   722.47
# 2016-07-31  699.21  700.65  692.1301  692.20  1344710    699.21   700.65
# 2016-08-31  772.88  780.43  761.0900  761.09  2700470    772.88   780.43
#
#               adjLow  adjOpen  adjVolume  divCash  splitFactor
# date
# 2016-06-30  713.1200   716.48    1306065      0.0          1.0
# 2016-07-31  692.1301   692.20    1344710      0.0          1.0
# 2016-08-31  761.0900   761.09    2700470      0.0          1.0

# %%
Stock Trend Overview

# %%
plt.figure(figsize = (10,20))
columns_to_plot = ['close', 'high', 'low', 'open', 'volume']

for index, i in enumerate(columns_to_plot):
    plt.subplot(8, 2, index + 1)
    plt.plot(df.index.values,df[i])
    plt.title(i,backgroundcolor='black',color='white',fontsize=15)
    plt.xlabel(i, size = 12)
plt.tight_layout()                     
plt.show()

# %% [markdown]
# Stock Moving Average

# %%
plt.figure(figsize=(9, 5))

data['MA10'] = data['close'].rolling(window=10).mean()
data['MA20'] = data['close'].rolling(window=20).mean()
data['MA30'] = data['close'].rolling(window=30).mean()

# Plotting the closing prices
plt.plot(data.index, data['close'], label='Close')

# Plotting the moving averages
plt.plot(data.index, data['MA10'], label='MA10')
plt.plot(data.index, data['MA20'], label='MA20')
plt.plot(data.index, data['MA30'], label='MA30')

plt.title('Closing Prices and Moving Averages')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# Stock Price Volatility

# %%
##measureing the volatility of a stock's price using pct_change

# %%
data['pct_change'] = data['close'].pct_change()

plt.figure(figsize=(15, 3))

# Plotting the percentage change
plt.plot(data.index, data['pct_change'], label='Daily Percentage Change')

plt.title('Daily Percentage Change of Closing Prices')
plt.xlabel('Date')
plt.ylabel('Percentage Change')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,3))
# Plotting the histogram
plt.hist(data['pct_change'], bins=50, alpha=0.7, color='blue', edgecolor='black')

# Adding a vertical line at the mean
mean_pct_change = data['pct_change'].mean()
plt.axvline(mean_pct_change, color='red', linestyle='dashed', linewidth=2, label=f'Mean: {mean_pct_change:.2%}')

# Adding a vertical line at one standard deviation above the mean
std_dev_pct_change = data['pct_change'].std()
plt.axvline(mean_pct_change + std_dev_pct_change, color='green', linestyle='dashed', linewidth=2, label=f'Std Dev: {std_dev_pct_change:.2%}')

# Adding a vertical line at one standard deviation below the mean
plt.axvline(mean_pct_change - std_dev_pct_change, color='green', linestyle='dashed', linewidth=2)

plt.title('Histogram of Percentage Change')
plt.xlabel('Percentage Change')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# Analysing Stock Returns

# %%
mean_return = data['pct_change'].mean()
std_dev_return = data['pct_change'].std()
skewness = data['pct_change'].skew()
kurtosis = data['pct_change'].kurtosis()

print(f"Mean Return: {mean_return:.4%}")
print(f"Standard Deviation: {std_dev_return:.4%}")
print(f"Skewness: {skewness:.4}")
print(f"Kurtosis: {kurtosis:.4}")
# Out:
# Mean Return: 0.1139%
# Standard Deviation: 1.6847%
# Skewness: -0.07836
# Kurtosis: 6.369

# %%
rolling_mean = data['pct_change'].rolling(window=20).mean()
rolling_std = data['pct_change'].rolling(window=20).std()

plt.figure(figsize=(12, 3))
plt.plot(data.index, data['pct_change'], label='Daily Returns')
plt.plot(data.index, rolling_mean, label='Rolling Mean (20 days)')
plt.plot(data.index, rolling_std, label='Rolling Std Dev (20 days)')
plt.title('Daily Returns and Rolling Statistics')
plt.xlabel('Date')
plt.ylabel('Percentage Change')
plt.legend()
plt.show()

# %%
#standard deviation for each days return
data['std_dev'] = data['pct_change'].rolling(window=20).std()

# %%
plt.figure(figsize=(8, 4))
plt.scatter(data['pct_change'], data['std_dev'], alpha=0.5)
plt.title('Risk-Return Analysis')
plt.xlabel('Daily Return')
plt.ylabel('Standard Deviation of Daily Returns')
plt.show()

# %% [markdown]
# BUilding Predictive Model

# %%
data = data.drop('date', axis=1)

# %%
data.head(1)
# Out:
#     close    high     low    open   volume  adjClose  adjHigh  adjLow  \
# 0  718.27  722.47  713.12  716.48  1306065    718.27   722.47  713.12
#
#    adjOpen  adjVolume  divCash  splitFactor  MA10  MA20  MA30  pct_change  \
# 0   716.48    1306065      0.0          1.0   NaN   NaN   NaN         NaN
#
#    std_dev
# 0      NaN

# %%
#seperating feature and target column
features = data.drop('close', axis=1)  # Exclude 'Close' column
target = data['close']

# %% [markdown]
# Scaling the data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# Scale the data using MinMaxScaler
scaler = MinMaxScaler()
features_scaled = scaler.fit_transform(features)

# %%
# Function to create sequences from time series data
def create_sequences(data, sequence_length):
    sequences, targets = [], []
    data_len = len(data)
    for i in range(data_len - sequence_length):
        seq = data[i:i+sequence_length]
        target_val = data[i+sequence_length]
        sequences.append(seq)
        targets.append(target_val)
    return np.array(sequences), np.array(targets)

# %%
# Define sequence length
sequence_length = 10

# %%
# Create sequences
X_seq, y_seq = create_sequences(features_scaled, sequence_length)

# %% [markdown]
# Splitting the data

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.2, random_state=42)

# %%
# Reshape input data for RNN models
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], features.shape[1]))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], features.shape[1]))

# %%
# Build RNN model
model_rnn = Sequential()
model_rnn.add(SimpleRNN(units=50, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])))
model_rnn.add(Dense(units=1))
model_rnn.compile(optimizer='adam', loss='mse')

# %%
# Build LSTM model
model_lstm = Sequential()
model_lstm.add(LSTM(units=50, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])))
model_lstm.add(Dense(units=1))
model_lstm.compile(optimizer='adam', loss='mse')

# %%
# Build GRU model
model_gru = Sequential()
model_gru.add(GRU(units=50, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])))
model_gru.add(Dense(units=1))
model_gru.compile(optimizer='adam', loss='mse')

# %%
# Train the models
model_rnn.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), verbose=0)
model_lstm.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), verbose=0)
model_gru.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), verbose=0)
